# %%
import matplotlib.pyplot as plt
import math

# %%
def normalize(vector: list):
    mag = math.sqrt(vector[0]**2 + vector[1]**2)
    return [vector[0] / mag, vector[1] / mag]

def dotproduct(vector1: list, vector2: list):
    return vector1[0] * vector2[0] + vector1[1] * vector2[1]

def generateOuterPoly(points: list, d: float):
    outerPnts = []

    for i in range(len(points)):
        thisPnt = points[i]
        prevPnt = points[i - 1]
        nextPnt = points[(i + 1) % len(points)]

        prevThis = [thisPnt[0] - prevPnt[0], thisPnt[1] - prevPnt[1]]
        thisNext = [nextPnt[0] - thisPnt[0], nextPnt[1] - thisPnt[1]]

        prevThis_normal_unit = normalize([-prevThis[1], prevThis[0]])
        thisNext_normal_unit = normalize([-thisNext[1], thisNext[0]])

        pointNormal_unit = normalize([prevThis_normal_unit[0] + thisNext_normal_unit[0], prevThis_normal_unit[1] + thisNext_normal_unit[1]])
        pointNormal_scaled = [pointNormal_unit[0] * d, pointNormal_unit[1] * d]

        prevThis_normal_unit_scaled = [prevThis_normal_unit[0] * d, prevThis_normal_unit[1] * d]
        thisNext_normal_unit_scaled = [thisNext_normal_unit[0] * d, thisNext_normal_unit[1] * d]

        theta = math.pi - math.acos(dotproduct(prevThis_normal_unit, thisNext_normal_unit))

        if theta >= math.pi / 2:
            movedPoint = [thisPnt[0] + pointNormal_scaled[0], thisPnt[1] + pointNormal_scaled[1]]
            outerPnts.append(movedPoint)
        else:
            movedPoint1 = [thisPnt[0] + prevThis_normal_unit_scaled[0], thisPnt[1] + prevThis_normal_unit_scaled[1]]
            movedPoint2 = [thisPnt[0] + thisNext_normal_unit_scaled[0], thisPnt[1] + thisNext_normal_unit_scaled[1]]
            outerPnts.append(movedPoint1)
            outerPnts.append(movedPoint2)


    return outerPnts

# %%
inX = [1.5, 1, 1, 2, 2, 3, 4
       , 3, 2]
inY = [1, 1, 2, 2, 3, 2, 1.5, 1, 0]
# inX = [1, 2, 3, 2]
# inY = [1, 3, 1, 2]
# inX = [0, 2, 4]
# inY = [0, 2, 0]

input = [(inX[i], inY[i]) for i in range(len(inX))]

newPnts = generateOuterPoly(input, 0.1)

outX = [pnt[0] for pnt in newPnts]
outY = [pnt[1] for pnt in newPnts]



## FOR DISPLYAING ONLY
inX.append(inX[0])
inY.append(inY[0])
outX.append(outX[0])
outY.append(outY[0])
## END FOR DISPLAYING



fig = plt.figure(dpi=100)
plt.plot(inX, inY)
plt.plot(outX, outY)
